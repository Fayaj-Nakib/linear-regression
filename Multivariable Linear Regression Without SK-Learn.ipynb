# %% [markdown]
# # Multivariable Linear Regression Without SK-Learn

# %%
import numpy as np # Numpy Header
import pandas as pd #Pandas Header 
import random #pseudo-random number generators

# %%
df = pd.read_csv('D:/Linear Regression/seattle-weather.csv') #Inserting Dataset

# %%
print(df.tail()) #Appending Rows
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6     fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4     sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5     sun

# %%
m = len(df.wind) #Length Of Dataset
print(m)
# Out:
# 1461

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder



# Extract the 'weather' column
weather = df['weather']

# Create a LabelEncoder
label_encoder = LabelEncoder()

# Encode the 'weather' column
weather_encoded = label_encoder.fit_transform(weather)

# Replace the original 'weather' column with the encoded values
df['weather'] = weather_encoded

# Now 'weather' is represented as numeric values
print(df.head())
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7        0
# 1  2012-01-02           10.9      10.6       2.8   4.5        2
# 2  2012-01-03            0.8      11.7       7.2   2.3        2
# 3  2012-01-04           20.3      12.2       5.6   4.7        2
# 4  2012-01-05            1.3       8.9       2.8   6.1        2

# %%
x1=df["precipitation"]
x2=df["temp_max"]
x3=df["temp_min"]
y= df["weather"]
print(x1.tail())
print(x2.head())
print(x3.head())
print(y.head())
len(x1)
# Out:
# 1456    8.6
# 1457    1.5
# 1458    0.0
# 1459    0.0
# 1460    0.0
# Name: precipitation, dtype: float64
# 0    12.8
# 1    10.6
# 2    11.7
# 3    12.2
# 4     8.9
# Name: temp_max, dtype: float64
# 0    5.0
# 1    2.8
# 2    7.2
# 3    5.6
# 4    2.8
# Name: temp_min, dtype: float64
# 0    0
# 1    2
# 2    2
# 3    2
# 4    2
# Name: weather, dtype: int32
# 1461

# %%
#Normalize Data , Pre Prosessing
from sklearn import preprocessing
n1=preprocessing.normalize([x1])
n2=preprocessing.normalize([x2])
n3=preprocessing.normalize([x3])
print(n1,n2,n3)
# Out:
# [[0.         0.03888872 0.00285422 ... 0.         0.         0.        ]] [[0.01859779 0.01540129 0.01699954 ... 0.01046126 0.00813653 0.00813653]] [[ 0.01356268  0.0075951   0.01953026 ...  0.00162752 -0.00271254
#   -0.00569633]]

# %%
#Initialization
x1=n1[0]
x2=n2[0]
x3=n3[0]
print(x1,x2,x3)
# Out:
# [0.         0.03888872 0.00285422 ... 0.         0.         0.        ] [0.01859779 0.01540129 0.01699954 ... 0.01046126 0.00813653 0.00813653] [ 0.01356268  0.0075951   0.01953026 ...  0.00162752 -0.00271254
#  -0.00569633]

# %%
#Learning rate
#Alpha = min(min(x1),min(x2),min(x3))/100
alpha=0.2
print(alpha)
# Out:
# 0.2

# %%
J = 100
n = 0 # Iteration Number
theta = [1,1.5, 8,9] 
cost_ls=[]

for i in range(100):

  print("Iteration number: ",n+1)
  n = n+1
  # Hypothesis Function
  h = []
  print("Hypothesis function value is: h0(x)=theta_0+theta_1 * x")
  for i2 in range(m):
    temp = theta[0] + theta[1]*x1[i2] + theta[2]*x2[i2]+theta[3]*x3[i2]
    h.append(temp)

  # Cost Function
  error_sum = 0 
  print("Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2")

  for i3 in range(m):
    error_sum = error_sum + (h[i3] - y[i3])**2

  J = (1/(2*m))*error_sum
  if J == float("inf") :
    theta = [random.randint(-100,100),random.randint(-100,100), random.randint(-100,100),random.randint(-100,100)] 
    continue
  print("\nCost function is:",J)
  cost_ls.append(J)

    # Gradient Descent
  print("\ngradient decent:")
  temp0 = 0
  for i4 in range(m):
    temp0 = temp0 + (h[i4] - y[i4])

  theta[0] = theta[0] - (alpha/m)*temp0

  temp1 = 0
  for i5 in range(m):
    temp1 = temp1 + (h[i5] - y[i5])*x1[i5]

  theta[1] = theta[1] - (alpha/m)*temp1

  temp1 = 0
  for i5 in range(m):
    temp1 = temp1 + (h[i5] - y[i5])*x2[i5]

  theta[2] = theta[2] - (alpha/m)*temp1
  
  temp1 = 0
  for i5 in range(m):
    temp1 = temp1 + (h[i5] - y[i5])*x3[i5]

  theta[3] = theta[3] - (alpha/m)*temp1

  print("New parameter value is: ",theta)

print("result coefficient is",theta)
# Out:
# Iteration number:  1
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 1.588155866453097
#
# gradient decent:
# New parameter value is:  [1.2687792645302285, 1.5013527885539288, 8.00684539514218, 9.005975988937976]
# Iteration number:  2
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 1.2627273524074412
#
# gradient decent:
# New parameter value is:  [1.4837403538730671, 1.5021238470284022, 8.012405039738228, 9.010749445258318]
# Iteration number:  3
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 1.054571982286392
#
# gradient decent:
# New parameter value is:  [1.6556596748768588, 1.5024296957423176, 8.016936383624516, 9.014561157452277]
# Iteration number:  4
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.9214269023744666
#
# gradient decent:
# New parameter value is:  [1.7931557955898425, 1.5023635232942825, 8.020645325573415, 9.017603699169959]
# Iteration number:  5
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.8362599314602372
#
# gradient decent:
# New parameter value is:  [1.9031215251131879, 1.5019998584437, 8.023696535740061, 9.020031083630771]
# Iteration number:  6
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.7817807363832677
#
# gradient decent:
# New parameter value is:  [1.9910694749432916, 1.5013983065069167, 8.026221711170075, 9.021966484860641]
# Iteration number:  7
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.7469300682260243
#
# gradient decent:
# New parameter value is:  [2.061408426037845, 1.5006065375874302, 8.028326178246566, 9.023508412849388]
# Iteration number:  8
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.7246342063443337
#
# gradient decent:
# New parameter value is:  [2.117664356881933, 1.4996626764508942, 8.030094173080855, 9.02473565221115]
# Iteration number:  9
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.7103686550761614
#
# gradient decent:
# New parameter value is:  [2.162657213487072, 1.4985972138579644, 8.031593064571922, 9.025711211940706]
# Iteration number:  10
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.7012394549302973
#
# gradient decent:
# New parameter value is:  [2.198642283439822, 1.4974345351769818, 8.032876731851763, 9.026485484281173]
# Iteration number:  11
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6953955705289305
#
# gradient decent:
# New parameter value is:  [2.227423261590129, 1.4961941429113528, 8.03398826544014, 9.027098771068513]
# Iteration number:  12
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6916530419788547
#
# gradient decent:
# New parameter value is:  [2.2504426757695315, 1.494891634431326, 8.034962127527358, 9.027583304207601]
# Iteration number:  13
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6892545844406311
#
# gradient decent:
# New parameter value is:  [2.2688542059061105, 1.4935394839273815, 8.03582587968781, 9.027964861573578]
# Iteration number:  14
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6877158231212952
#
# gradient decent:
# New parameter value is:  [2.28358052215386, 1.4921476677873695, 8.036601564640797, 9.028264059349445]
# Iteration number:  15
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6867269420468499
#
# gradient decent:
# New parameter value is:  [2.2953595416701753, 1.49072416474981, 8.037306811331268, 9.028497385589457]
# Iteration number:  16
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6860897766158695
#
# gradient decent:
# New parameter value is:  [2.3047814230603034, 1.489275355907836, 8.037955718732153, 9.02867802682455]
# Iteration number:  17
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6856775767167458
#
# gradient decent:
# New parameter value is:  [2.312318153153468, 1.487806344617421, 8.038559562676495, 9.028816529150516]
# Iteration number:  18
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6854092703986985
#
# gradient decent:
# New parameter value is:  [2.318347209402312, 1.486321212348041, 8.039127361155405, 9.028921326941642]
# Iteration number:  19
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6852330023921032
#
# gradient decent:
# New parameter value is:  [2.3231704841869463, 1.4848232233024852, 8.039666326422275, 9.028999165696174]
# Iteration number:  20
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6851156050110973
#
# gradient decent:
# New parameter value is:  [2.3270294197671197, 1.4833149880641467, 8.040182226568856, 9.029055440212316]
# Iteration number:  21
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6850358635286592
#
# gradient decent:
# New parameter value is:  [2.3301171126521676, 1.481798594476017, 8.040679674700312, 9.029094465048786]
# Iteration number:  22
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.684980208573456
#
# gradient decent:
# New parameter value is:  [2.332587994224388, 1.4802757123128223, 8.041162360206632, 9.029119690829074]
# Iteration number:  23
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6849399608992308
#
# gradient decent:
# New parameter value is:  [2.3345655729403623, 1.4787476769938919, 8.04163323372488, 9.02913387723351]
# Iteration number:  24
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.684909569083231
#
# gradient decent:
# New parameter value is:  [2.336148626254653, 1.4772155565335865, 8.042094655065101, 9.029139231351877]
# Iteration number:  25
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6848854823222534
#
# gradient decent:
# New parameter value is:  [2.3374161526893062, 1.4756802050857525, 8.042548511515937, 9.029137518332652]
# Iteration number:  26
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6848654294500782
#
# gradient decent:
# New parameter value is:  [2.338431332314244, 1.4741423057665781, 8.042996312461046, 9.02913014987615]
# Iteration number:  27
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6848479577823336
#
# gradient decent:
# New parameter value is:  [2.3392446941916853, 1.4726024049027158, 8.04343926504978, 9.029118255008036]
# Iteration number:  28
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6848321381522935
#
# gradient decent:
# New parameter value is:  [2.339896649579993, 1.4710609394216518, 8.043878334715775, 9.029102736681342]
# Iteration number:  29
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6848173762457695
#
# gradient decent:
# New parameter value is:  [2.3404195178955756, 1.4695182587575035, 8.044314293577452, 9.029084317044639]
# Iteration number:  30
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6848032919270736
#
# gradient decent:
# New parameter value is:  [2.340839147001617, 1.467974642370456, 8.044747759146945, 9.02906357364584]
# Iteration number:  31
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6847896420534416
#
# gradient decent:
# New parameter value is:  [2.3411762090545327, 1.466430313758156, 8.045179225288043, 9.029040968386646]
# Iteration number:  32
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6847762711055723
#
# gradient decent:
# New parameter value is:  [2.3414472368736106, 1.4648854516615006, 8.045609086975206, 9.029016870679238]
# Iteration number:  33
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6847630796099101
#
# gradient decent:
# New parameter value is:  [2.3416654527907723, 1.4633401990266093, 8.046037660094894, 9.028991575966124]
# Iteration number:  34
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6847500039409093
#
# gradient decent:
# New parameter value is:  [2.3418414315336853, 1.4617946701722746, 8.046465197281943, 9.028965320531634]
# Iteration number:  35
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6847370034021281
#
# gradient decent:
# New parameter value is:  [2.341983630374935, 1.4602489565222216, 8.046891900584894, 9.02893829334759]
# Iteration number:  36
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6847240519630586
#
# gradient decent:
# New parameter value is:  [2.3420988131255505, 1.458703131189556, 8.047317931595261, 9.028910645547036]
# Iteration number:  37
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6847111329738103
#
# gradient decent:
# New parameter value is:  [2.3421923892292056, 1.4571572526432328, 8.047743419548537, 9.028882498000977]
# Iteration number:  38
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846982357845354
#
# gradient decent:
# New parameter value is:  [2.342268684957103, 1.4556113676403633, 8.048168467803075, 9.028853947377964]
# Iteration number:  39
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846853535831336
#
# gradient decent:
# New parameter value is:  [2.342331160299525, 1.4540655135713632, 8.04859315902166, 9.028825070990335]
# Iteration number:  40
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846724820122063
#
# gradient decent:
# New parameter value is:  [2.3423825824276023, 1.452519720335515, 8.04901755931553, 9.02879593067004]
# Iteration number:  41
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846596182844255
#
# gradient decent:
# New parameter value is:  [2.3424251644215612, 1.450974011840973, 8.049441721558615, 9.028766575868403]
# Iteration number:  42
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846467606167227
#
# gradient decent:
# New parameter value is:  [2.3424606762204006, 1.449428407204412, 8.049865688038143, 9.028737046135182]
# Iteration number:  43
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846339078683709
#
# gradient decent:
# New parameter value is:  [2.342490533355302, 1.447882921710459, 8.050289492574485, 9.02870737310123]
# Iteration number:  44
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846210593094905
#
# gradient decent:
# New parameter value is:  [2.3425158679153006, 1.4463375675790144, 8.050713162216546, 9.028677582064157]
# Iteration number:  45
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6846082144730014
#
# gradient decent:
# New parameter value is:  [2.3425375853029813, 1.4447923545789247, 8.051136718597657, 9.028647693256481]
# Iteration number:  46
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845953730599024
#
# gradient decent:
# New parameter value is:  [2.3425564096255633, 1.4432472905187748, 8.05156017901998, 9.028617722859847]
# Iteration number:  47
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845825348787065
#
# gradient decent:
# New parameter value is:  [2.342572919997, 1.4417023816394061, 8.051983557321764, 9.028587683816166]
# Iteration number:  48
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845696998066988
#
# gradient decent:
# New parameter value is:  [2.34258757957104, 1.4401576329278387, 8.052406864570957, 9.028557586476328]
# Iteration number:  49
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845568677651372
#
# gradient decent:
# New parameter value is:  [2.3426007587607884, 1.4386130483683328, 8.052830109619915, 9.028527439119022]
# Iteration number:  50
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845440387034227
#
# gradient decent:
# New parameter value is:  [2.342612753808844, 1.4370686311431793, 8.053253299549054, 9.02849724836567]
# Iteration number:  51
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845312125889523
#
# gradient decent:
# New parameter value is:  [2.342623801639003, 1.4355243837932845, 8.053676440021654, 9.028467019512266]
# Iteration number:  52
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845183894006189
#
# gradient decent:
# New parameter value is:  [2.3426340917340958, 1.4339803083465998, 8.054099535567623, 9.02843675679479]
# Iteration number:  53
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6845055691247013
#
# gradient decent:
# New parameter value is:  [2.34264377563544, 1.432436406420835, 8.054522589810441, 9.028406463601447]
# Iteration number:  54
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6844927517521634
#
# gradient decent:
# New parameter value is:  [2.3426529745401474, 1.4308926793056043, 8.05494560564866, 9.028376142642433]
# Iteration number:  55
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6844799372769931
#
# gradient decent:
# New parameter value is:  [2.3426617853771643, 1.4293491280281234, 8.055368585401064, 9.028345796085693]
# Iteration number:  56
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6844671256951025
#
# gradient decent:
# New parameter value is:  [2.342670285666666, 1.4278057534057527, 8.055791530922756, 9.028315425665504]
# Iteration number:  57
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.684454317003638
#
# gradient decent:
# New parameter value is:  [2.342678537406416, 1.4262625560880182, 8.056214443698005, 9.028285032769308]
# Iteration number:  58
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6844415112005319
#
# gradient decent:
# New parameter value is:  [2.3426865901799325, 1.4247195365902188, 8.056637324914506, 9.02825461850716]
# Iteration number:  59
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6844287082842235
#
# gradient decent:
# New parameter value is:  [2.3426944836422834, 1.4231766953203038, 8.057060175522759, 9.028224183767279]
# Iteration number:  60
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6844159082534683
#
# gradient decent:
# New parameter value is:  [2.3427022495081324, 1.4216340326003694, 8.057482996283564, 9.028193729260455]
# Iteration number:  61
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6844031111072364
#
# gradient decent:
# New parameter value is:  [2.342709913141704, 1.4200915486838492, 8.057905787806014, 9.028163255555588]
# Iteration number:  62
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6843903168446263
#
# gradient decent:
# New parameter value is:  [2.34271749482838, 1.4185492437692648, 8.05832855057786, 9.028132763108099]
# Iteration number:  63
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6843775254648209
#
# gradient decent:
# New parameter value is:  [2.342725010791671, 1.4170071180112205, 8.05875128498982, 9.028102252282642]
# Iteration number:  64
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6843647369670528
#
# gradient decent:
# New parameter value is:  [2.342732474006556, 1.4154651715291984, 8.059173991355, 9.028071723371292]
# Iteration number:  65
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6843519513505989
#
# gradient decent:
# New parameter value is:  [2.34273989484996, 1.4139234044145912, 8.059596669924439, 9.02804117660807]
# Iteration number:  66
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6843391686147524
#
# gradient decent:
# New parameter value is:  [2.342747281620979, 1.4123818167363273, 8.060019320899535, 9.028010612180571]
# Iteration number:  67
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.684326388758821
#
# gradient decent:
# New parameter value is:  [2.3427546409569433, 1.4108404085453703, 8.060441944441989, 9.027980030239258]
# Iteration number:  68
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6843136117821184
#
# gradient decent:
# New parameter value is:  [2.34276197816616, 1.4092991798783152, 8.060864540681747, 9.027949430904899]
# Iteration number:  69
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6843008376839729
#
# gradient decent:
# New parameter value is:  [2.3427692974940366, 1.4077581307602673, 8.061287109723366, 9.02791881427451]
# Iteration number:  70
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6842880664637111
#
# gradient decent:
# New parameter value is:  [2.342776602335912, 1.406217261207143, 8.06170965165109, 9.027888180426116]
# Iteration number:  71
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.684275298120661
#
# gradient decent:
# New parameter value is:  [2.3427838954072713, 1.4046765712275098, 8.062132166532926, 9.027857529422548]
# Iteration number:  72
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6842625326541567
#
# gradient decent:
# New parameter value is:  [2.3427911788798785, 1.4031360608240586, 8.062554654423884, 9.027826861314491]
# Iteration number:  73
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6842497700635275
#
# gradient decent:
# New parameter value is:  [2.34279845449065, 1.4015957299947812, 8.062977115368593, 9.02779617614291]
# Iteration number:  74
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6842370103481072
#
# gradient decent:
# New parameter value is:  [2.342805723628728, 1.4000555787339113, 8.063399549403366, 9.027765473941002]
# Iteration number:  75
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6842242535072328
#
# gradient decent:
# New parameter value is:  [2.342812987405115, 1.3985156070326776, 8.063821956557875, 9.027734754735748]
# Iteration number:  76
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6842114995402344
#
# gradient decent:
# New parameter value is:  [2.342820246708371, 1.396975814879906, 8.06424433685648, 9.027704018549159]
# Iteration number:  77
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6841987484464497
#
# gradient decent:
# New parameter value is:  [2.3428275022491536, 1.3954362022625015, 8.064666690319282, 9.027673265399267]
# Iteration number:  78
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6841860002252114
#
# gradient decent:
# New parameter value is:  [2.34283475459584, 1.3938967691658328, 8.065089016962991, 9.027642495300931]
# Iteration number:  79
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.684173254875857
#
# gradient decent:
# New parameter value is:  [2.342842004203017, 1.3923575155740406, 8.065511316801595, 9.027611708266463]
# Iteration number:  80
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6841605123977184
#
# gradient decent:
# New parameter value is:  [2.342849251434268, 1.3908184414702844, 8.065933589846907, 9.02758090430614]
# Iteration number:  81
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6841477727901338
#
# gradient decent:
# New parameter value is:  [2.3428564965803917, 1.3892795468369388, 8.066355836109, 9.027550083428617]
# Iteration number:  82
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6841350360524372
#
# gradient decent:
# New parameter value is:  [2.3428637398739807, 1.3877408316557514, 8.06677805559656, 9.027519245641244]
# Iteration number:  83
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6841223021839653
#
# gradient decent:
# New parameter value is:  [2.342870981501072, 1.386202295907969, 8.067200248317153, 9.027488390950333]
# Iteration number:  84
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6841095711840565
#
# gradient decent:
# New parameter value is:  [2.342878221610473, 1.3846639395744382, 8.067622414277464, 9.027457519361365]
# Iteration number:  85
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840968430520405
#
# gradient decent:
# New parameter value is:  [2.342885460321214, 1.3831257626356863, 8.06804455348346, 9.02742663087915]
# Iteration number:  86
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840841177872581
#
# gradient decent:
# New parameter value is:  [2.3428926977285114, 1.381587765071985, 8.068466665940543, 9.027395725507972]
# Iteration number:  87
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840713953890464
#
# gradient decent:
# New parameter value is:  [2.342899933908536, 1.3800499468634029, 8.068888751653656, 9.027364803251686]
# Iteration number:  88
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840586758567382
#
# gradient decent:
# New parameter value is:  [2.3429071689222263, 1.3785123079898458, 8.06931081062738, 9.027333864113805]
# Iteration number:  89
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840459591896748
#
# gradient decent:
# New parameter value is:  [2.3429144028183395, 1.3769748484310909, 8.069732842866003, 9.027302908097573]
# Iteration number:  90
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840332453871891
#
# gradient decent:
# New parameter value is:  [2.34292163563589, 1.3754375681668118, 8.070154848373582, 9.027271935206015]
# Iteration number:  91
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840205344486218
#
# gradient decent:
# New parameter value is:  [2.342928867406101, 1.3739004671766009, 8.070576827153985, 9.02724094544198]
# Iteration number:  92
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6840078263733064
#
# gradient decent:
# New parameter value is:  [2.3429360981539618, 1.3723635454399847, 8.070998779210933, 9.027209938808179]
# Iteration number:  93
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6839951211605791
#
# gradient decent:
# New parameter value is:  [2.342943327899481, 1.3708268029364392, 8.071420704548025, 9.02717891530721]
# Iteration number:  94
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6839824188097838
#
# gradient decent:
# New parameter value is:  [2.342950556658679, 1.3692902396453992, 8.071842603168767, 9.027147874941583]
# Iteration number:  95
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6839697193202546
#
# gradient decent:
# New parameter value is:  [2.342957784444389, 1.3677538555462676, 8.072264475076588, 9.027116817713738]
# Iteration number:  96
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.683957022691326
#
# gradient decent:
# New parameter value is:  [2.3429650112668963, 1.3662176506184218, 8.072686320274855, 9.027085743626053]
# Iteration number:  97
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6839443289223412
#
# gradient decent:
# New parameter value is:  [2.342972237134445, 1.36468162484122, 8.073108138766885, 9.027054652680864]
# Iteration number:  98
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6839316380126361
#
# gradient decent:
# New parameter value is:  [2.34297946205365, 1.3631457781940046, 8.073529930555958, 9.02702354488047]
# Iteration number:  99
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6839189499615499
#
# gradient decent:
# New parameter value is:  [2.342986686029821, 1.3616101106561072, 8.07395169564532, 9.02699242022714]
# Iteration number:  100
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2
#
# Cost function is: 0.6839062647684186
#
# gradient decent:
# New parameter value is:  [2.342993909067226, 1.3600746222068496, 8.074373434038195, 9.02696127872312]
# result coefficient is [2.342993909067226, 1.3600746222068496, 8.074373434038195, 9.02696127872312]

# %%
import matplotlib.pyplot as plt

x= [i for i in range(0,100)]

plt.plot(x, cost_ls)
 
# Naming The X Axis
plt.xlabel('Epochs')
# Naming The Y Axis
plt.ylabel('Cost Function')
 
# Function To Show The Plot
plt.show()

# %%
#Display Plot 
fig = plt.figure(figsize = (20,15))
ax = fig.gca()
df.hist(ax=ax)
plt.show()
# Out:
# C:\Users\nakib\AppData\Local\Temp\ipykernel_13880\3300527310.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax)

# %%
#Seaborn Visualization Library
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create The Default Pairplot
#Printing Pairwise Plot
sns.pairplot(df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' contains your preprocessed dataset
# Select only the numeric columns for correlation calculations
numeric_columns = df.select_dtypes(include=[float, int])

# Calculate the correlation matrix for numeric columns
correlation_matrix = numeric_columns.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()
